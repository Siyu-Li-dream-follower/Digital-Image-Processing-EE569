# %%
# EE569 HOMEWORK ASSIGNMENT 5
# DATE: Aprile 14th 2021
# NAME: Siyu Li
# ID:2455870216
# E-mail:lisiyu@usc.edu

### To test the performance under the condition that the test set is reversed in intensity
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras.initializers import Ones, he_normal, GlorotNormal
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt
from keras.models import Sequential

# training parameter
mini_batch_size = 64
number_epochs = 40
learning_rate = 0.0005
number_class=10

kernel_initial = Ones(), he_normal(), GlorotNormal()
kernel_regularizer = l1(0.001), l2(0.001)
# load data
(train_data, train_label), (test_data, test_label) = mnist.load_data()

img_rows=np.shape(train_data)[1]
img_cols=np.shape(train_data)[2]

train_data = train_data.reshape(train_data.shape[0], img_rows, img_cols, 1)
test_data = test_data.reshape(test_data.shape[0], img_rows, img_cols, 1)

train_data = np.pad(train_data,((0,0), (2,2), (2,2), (0,0)), 'constant')
test_data = np.pad(test_data,((0,0), (2,2), (2,2), (0,0)), 'constant')

##np.shape(train_data)
train_label = to_categorical(train_label, number_class)
test_label = to_categorical(test_label, number_class)
# normalize data
train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255
### reverse the test data
test_data=1-test_data
###np.shape(train_data) # (60000,28,28)
###input_shape = np.shape(train_data)[1:] # python start from zero, the zero th is the number of images
####K.image_data_format()

###build sequential model
model = keras.Sequential()

model.add(Conv2D(filters=6, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu', input_shape=(32,32,1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=16, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(units=120, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=84, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=10, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),#SGD(learning_rate=learning_rate),
              metrics=['accuracy'])

model.summary()
### training
training_process=model.fit(train_data, train_label,
          batch_size=mini_batch_size,
          epochs=number_epochs,
          verbose=1,
          validation_data=(test_data, test_label))

scores = model.evaluate(test_data, test_label, verbose=0)

print('LeNet 5 Training Error: %.4f%%' % (100-training_process.history['accuracy'][number_epochs-1]*100))
print('LeNet 5 Training Loss: %.4f%%' % (training_process.history['loss'][number_epochs-1]*100))
print('LeNet 5 Training Accuracy: %.4f%%' % (training_process.history['accuracy'][number_epochs-1]*100))

print('LeNet 5 Test Error: %.4f%%' % (100-scores[1]*100))
print('LeNet 5 Test Loss: %.4f%%' % (scores[0]*100))
print('LeNet 5 Test Accuracy: %.4f%%' % (scores[1]*100))

plt.figure()
plt.plot(training_process.history['accuracy'], label='train')
plt.plot(training_process.history['val_accuracy'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.figure()
plt.plot(training_process.history['loss'], label='train')
plt.plot(training_process.history['val_loss'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Multiclass Cross Entropy')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 938/938 [==============================] - 23s 23ms/step - loss: 0.8900 - accuracy: 0.8424 - val_loss: 7.3846 - val_accuracy: 0.0382
# Epoch 2/40
# 938/938 [==============================] - 21s 22ms/step - loss: 0.3397 - accuracy: 0.9715 - val_loss: 6.2367 - val_accuracy: 0.0677
# Epoch 3/40
# 938/938 [==============================] - 21s 23ms/step - loss: 0.2694 - accuracy: 0.9798 - val_loss: 4.0889 - val_accuracy: 0.1459
# Epoch 4/40
# 938/938 [==============================] - 21s 22ms/step - loss: 0.2251 - accuracy: 0.9838 - val_loss: 3.6129 - val_accuracy: 0.1830
# Epoch 5/40
# 938/938 [==============================] - 21s 22ms/step - loss: 0.1930 - accuracy: 0.9862 - val_loss: 3.5848 - val_accuracy: 0.1578
# Epoch 6/40
# 938/938 [==============================] - 20s 22ms/step - loss: 0.1755 - accuracy: 0.9848 - val_loss: 3.2796 - val_accuracy: 0.2475
# Epoch 7/40
# 938/938 [==============================] - 20s 22ms/step - loss: 0.1590 - accuracy: 0.9863 - val_loss: 3.1479 - val_accuracy: 0.2550
# Epoch 8/40
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1465 - accuracy: 0.9875 - val_loss: 2.9588 - val_accuracy: 0.2844
# Epoch 9/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1341 - accuracy: 0.9884 - val_loss: 2.6817 - val_accuracy: 0.2957
# Epoch 10/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1284 - accuracy: 0.9889 - val_loss: 2.8333 - val_accuracy: 0.2785
# Epoch 11/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1238 - accuracy: 0.9893 - val_loss: 2.8488 - val_accuracy: 0.3138
# Epoch 12/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1210 - accuracy: 0.9886 - val_loss: 2.7189 - val_accuracy: 0.2759
# Epoch 13/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1172 - accuracy: 0.9897 - val_loss: 2.4702 - val_accuracy: 0.2900
# Epoch 14/40
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1141 - accuracy: 0.9903 - val_loss: 2.7802 - val_accuracy: 0.2835
# Epoch 15/40
# 938/938 [==============================] - 14s 14ms/step - loss: 0.1114 - accuracy: 0.9896 - val_loss: 2.3250 - val_accuracy: 0.3647
# Epoch 16/40
# 938/938 [==============================] - 14s 14ms/step - loss: 0.1098 - accuracy: 0.9901 - val_loss: 2.5327 - val_accuracy: 0.3305
# Epoch 17/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1074 - accuracy: 0.9902 - val_loss: 2.4123 - val_accuracy: 0.3355
# Epoch 18/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1072 - accuracy: 0.9903 - val_loss: 2.2513 - val_accuracy: 0.3819
# Epoch 19/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1058 - accuracy: 0.9907 - val_loss: 2.3013 - val_accuracy: 0.3807
# Epoch 20/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1037 - accuracy: 0.9907 - val_loss: 2.1395 - val_accuracy: 0.4006
# Epoch 21/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1035 - accuracy: 0.9908 - val_loss: 2.1557 - val_accuracy: 0.3952
# Epoch 22/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1041 - accuracy: 0.9903 - val_loss: 2.3884 - val_accuracy: 0.3484
# Epoch 23/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1022 - accuracy: 0.9904 - val_loss: 2.7675 - val_accuracy: 0.3221
# Epoch 24/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1024 - accuracy: 0.9907 - val_loss: 2.1518 - val_accuracy: 0.3886
# Epoch 25/40
# 938/938 [==============================] - 13s 13ms/step - loss: 0.1012 - accuracy: 0.9912 - val_loss: 2.3360 - val_accuracy: 0.3785
# Epoch 26/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1016 - accuracy: 0.9900 - val_loss: 2.5612 - val_accuracy: 0.3443
# Epoch 27/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0993 - accuracy: 0.9916 - val_loss: 2.2723 - val_accuracy: 0.3774
# Epoch 28/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1009 - accuracy: 0.9904 - val_loss: 2.2319 - val_accuracy: 0.4137
# Epoch 29/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0991 - accuracy: 0.9915 - val_loss: 2.4117 - val_accuracy: 0.3419
# Epoch 30/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0997 - accuracy: 0.9912 - val_loss: 2.4871 - val_accuracy: 0.3317
# Epoch 31/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0990 - accuracy: 0.9911 - val_loss: 2.3458 - val_accuracy: 0.3985
# Epoch 32/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0996 - accuracy: 0.9908 - val_loss: 2.0322 - val_accuracy: 0.4386
# Epoch 33/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0979 - accuracy: 0.9914 - val_loss: 2.1677 - val_accuracy: 0.4170
# Epoch 34/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0982 - accuracy: 0.9907 - val_loss: 2.4162 - val_accuracy: 0.3572
# Epoch 35/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0967 - accuracy: 0.9919 - val_loss: 2.2090 - val_accuracy: 0.3857
# Epoch 36/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0957 - accuracy: 0.9920 - val_loss: 2.3049 - val_accuracy: 0.3552
# Epoch 37/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0958 - accuracy: 0.9919 - val_loss: 2.2287 - val_accuracy: 0.4079
# Epoch 38/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0960 - accuracy: 0.9920 - val_loss: 2.0873 - val_accuracy: 0.4027
# Epoch 39/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0978 - accuracy: 0.9910 - val_loss: 2.1519 - val_accuracy: 0.4216
# Epoch 40/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0966 - accuracy: 0.9914 - val_loss: 2.3571 - val_accuracy: 0.4080
# LeNet 5 Training Error: 0.8717%
# LeNet 5 Training Loss: 9.6835%
# LeNet 5 Training Accuracy: 99.1283%
# LeNet 5 Test Error: 59.2000%
# LeNet 5 Test Loss: 235.7133%
# LeNet 5 Test Accuracy: 40.8000%
# Text(0, 0.5, 'Multiclass Cross Entropy')
