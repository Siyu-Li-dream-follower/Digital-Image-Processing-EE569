# %%
# EE569 HOMEWORK ASSIGNMENT 5
# DATE: Aprile 14th 2021
# NAME: Siyu Li
# ID:2455870216
# E-mail:lisiyu@usc.edu

### To test the performance under the condition that the test set is reversed in intensity and the training set is refined
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras.initializers import Ones, he_normal, GlorotNormal
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt
from keras.models import Sequential

# %%
# training parameter
mini_batch_size = 64
number_epochs = 40
learning_rate = 0.0005
number_class=10

kernel_initial = Ones(), he_normal(), GlorotNormal()
kernel_regularizer = l1(0.001), l2(0.001)
# load data
(train_data, train_label), (test_data, test_label) = mnist.load_data()

img_rows=np.shape(train_data)[1]
img_cols=np.shape(train_data)[2]

train_data = train_data.reshape(train_data.shape[0], img_rows, img_cols, 1)
test_data = test_data.reshape(test_data.shape[0], img_rows, img_cols, 1)

train_data = np.pad(train_data,((0,0), (2,2), (2,2), (0,0)), 'constant')
test_data = np.pad(test_data,((0,0), (2,2), (2,2), (0,0)), 'constant')

##np.shape(train_data)
train_label = to_categorical(train_label, number_class)
test_label = to_categorical(test_label, number_class)
# normalize data
train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255

train_data_reverse=1-train_data[0:30000,]
train_data_positive=train_data[30000:,]
train_data=tf.concat([train_data_reverse,train_data_positive],axis=0)
np.shape(train_data)


## reverse the test data
test_data=1-test_data
### plot reversed image sample
plt.imshow(test_data[0],cmap='gray')
plt.show()

# %%
###np.shape(train_data) # (60000,28,28)
###input_shape = np.shape(train_data)[1:] # python start from zero, the zero th is the number of images
####K.image_data_format()

###build sequential model
model = keras.Sequential()

model.add(Conv2D(filters=6, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu', input_shape=(32,32,1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=16, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(units=120, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=84, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=10, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),#SGD(learning_rate=learning_rate),
              metrics=['accuracy'])

model.summary()
### training
training_process=model.fit(train_data, train_label,
          batch_size=mini_batch_size,
          epochs=number_epochs,
          verbose=1,
          validation_data=(test_data, test_label))

scores = model.evaluate(test_data, test_label, verbose=0)

print('LeNet 5 Training Error: %.4f%%' % (100-training_process.history['accuracy'][number_epochs-1]*100))
print('LeNet 5 Training Loss: %.4f%%' % (training_process.history['loss'][number_epochs-1]*100))
print('LeNet 5 Training Accuracy: %.4f%%' % (training_process.history['accuracy'][number_epochs-1]*100))

print('LeNet 5 Test Error: %.4f%%' % (100-scores[1]*100))
print('LeNet 5 Test Loss: %.4f%%' % (scores[0]*100))
print('LeNet 5 Test Accuracy: %.4f%%' % (scores[1]*100))

plt.figure()
plt.plot(training_process.history['accuracy'], label='train')
plt.plot(training_process.history['val_accuracy'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.figure()
plt.plot(training_process.history['loss'], label='train')
plt.plot(training_process.history['val_loss'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Multiclass Cross Entropy')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 938/938 [==============================] - 13s 13ms/step - loss: 1.2235 - accuracy: 0.7417 - val_loss: 0.4959 - val_accuracy: 0.9456
# Epoch 2/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.4358 - accuracy: 0.9642 - val_loss: 0.3730 - val_accuracy: 0.9683
# Epoch 3/40
# 938/938 [==============================] - 11s 11ms/step - loss: 0.3464 - accuracy: 0.9730 - val_loss: 0.2968 - val_accuracy: 0.9782
# Epoch 4/40
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2927 - accuracy: 0.9776 - val_loss: 0.2614 - val_accuracy: 0.9802
# Epoch 5/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.2548 - accuracy: 0.9790 - val_loss: 0.2516 - val_accuracy: 0.9738
# Epoch 6/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.2258 - accuracy: 0.9809 - val_loss: 0.2188 - val_accuracy: 0.9777
# Epoch 7/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.2013 - accuracy: 0.9834 - val_loss: 0.2089 - val_accuracy: 0.9762
# Epoch 8/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1867 - accuracy: 0.9837 - val_loss: 0.1793 - val_accuracy: 0.9814
# Epoch 9/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1724 - accuracy: 0.9840 - val_loss: 0.1716 - val_accuracy: 0.9825
# Epoch 10/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1626 - accuracy: 0.9859 - val_loss: 0.1588 - val_accuracy: 0.9827
# Epoch 11/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1552 - accuracy: 0.9852 - val_loss: 0.1692 - val_accuracy: 0.9790
# Epoch 12/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1477 - accuracy: 0.9861 - val_loss: 0.1564 - val_accuracy: 0.9822
# Epoch 13/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1456 - accuracy: 0.9861 - val_loss: 0.1478 - val_accuracy: 0.9839
# Epoch 14/40
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1392 - accuracy: 0.9870 - val_loss: 0.1479 - val_accuracy: 0.9843
# Epoch 15/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1385 - accuracy: 0.9867 - val_loss: 0.1509 - val_accuracy: 0.9807
# Epoch 16/40
# 938/938 [==============================] - 13s 14ms/step - loss: 0.1366 - accuracy: 0.9862 - val_loss: 0.1372 - val_accuracy: 0.9853
# Epoch 17/40
# 938/938 [==============================] - 13s 13ms/step - loss: 0.1299 - accuracy: 0.9880 - val_loss: 0.1408 - val_accuracy: 0.9849
# Epoch 18/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1292 - accuracy: 0.9883 - val_loss: 0.1390 - val_accuracy: 0.9837
# Epoch 19/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1297 - accuracy: 0.9874 - val_loss: 0.1239 - val_accuracy: 0.9887
# Epoch 20/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1258 - accuracy: 0.9875 - val_loss: 0.1285 - val_accuracy: 0.9864
# Epoch 21/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1239 - accuracy: 0.9892 - val_loss: 0.1292 - val_accuracy: 0.9873
# Epoch 22/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1231 - accuracy: 0.9888 - val_loss: 0.1361 - val_accuracy: 0.9828
# Epoch 23/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1207 - accuracy: 0.9892 - val_loss: 0.1227 - val_accuracy: 0.9882
# Epoch 24/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1209 - accuracy: 0.9884 - val_loss: 0.1311 - val_accuracy: 0.9859
# Epoch 25/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1213 - accuracy: 0.9888 - val_loss: 0.1250 - val_accuracy: 0.9867
# Epoch 26/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1196 - accuracy: 0.9892 - val_loss: 0.1197 - val_accuracy: 0.9888
# Epoch 27/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1179 - accuracy: 0.9895 - val_loss: 0.1216 - val_accuracy: 0.9880
# Epoch 28/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1172 - accuracy: 0.9897 - val_loss: 0.1201 - val_accuracy: 0.9894
# Epoch 29/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1184 - accuracy: 0.9887 - val_loss: 0.1220 - val_accuracy: 0.9869
# Epoch 30/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1147 - accuracy: 0.9901 - val_loss: 0.1187 - val_accuracy: 0.9889
# Epoch 31/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1134 - accuracy: 0.9903 - val_loss: 0.1209 - val_accuracy: 0.9866
# Epoch 32/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1149 - accuracy: 0.9902 - val_loss: 0.1173 - val_accuracy: 0.9880
# Epoch 33/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1129 - accuracy: 0.9901 - val_loss: 0.1173 - val_accuracy: 0.9885
# Epoch 34/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1152 - accuracy: 0.9894 - val_loss: 0.1166 - val_accuracy: 0.9889
# Epoch 35/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1125 - accuracy: 0.9909 - val_loss: 0.1177 - val_accuracy: 0.9884
# Epoch 36/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1111 - accuracy: 0.9905 - val_loss: 0.1238 - val_accuracy: 0.9858
# Epoch 37/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1116 - accuracy: 0.9905 - val_loss: 0.1151 - val_accuracy: 0.9883
# Epoch 38/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1097 - accuracy: 0.9916 - val_loss: 0.1295 - val_accuracy: 0.9829
# Epoch 39/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1106 - accuracy: 0.9908 - val_loss: 0.1243 - val_accuracy: 0.9844
# Epoch 40/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1100 - accuracy: 0.9912 - val_loss: 0.1170 - val_accuracy: 0.9885
# LeNet 5 Training Error: 1.0000%
# LeNet 5 Training Loss: 11.2605%
# LeNet 5 Training Accuracy: 99.0000%
# LeNet 5 Test Error: 1.1500%
# LeNet 5 Test Loss: 11.6984%
# LeNet 5 Test Accuracy: 98.8500%
# Text(0, 0.5, 'Multiclass Cross Entropy')

# %%
### To test the performance under the condition that the test set is original and the training set is refined
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras.initializers import Ones, he_normal, GlorotNormal
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt
from keras.models import Sequential

# training parameter
mini_batch_size = 64
number_epochs = 40
learning_rate = 0.0005
number_class=10

kernel_initial = Ones(), he_normal(), GlorotNormal()
kernel_regularizer = l1(0.001), l2(0.001)
# load data
(train_data, train_label), (test_data, test_label) = mnist.load_data()

img_rows=np.shape(train_data)[1]
img_cols=np.shape(train_data)[2]

train_data = train_data.reshape(train_data.shape[0], img_rows, img_cols, 1)
test_data = test_data.reshape(test_data.shape[0], img_rows, img_cols, 1)

train_data = np.pad(train_data,((0,0), (2,2), (2,2), (0,0)), 'constant')
test_data = np.pad(test_data,((0,0), (2,2), (2,2), (0,0)), 'constant')

##np.shape(train_data)
train_label = to_categorical(train_label, number_class)
test_label = to_categorical(test_label, number_class)
# normalize data
train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255

train_data_reverse=1-train_data[0:30000,]
train_data_positive=train_data[30000:,]
train_data=tf.concat([train_data_reverse,train_data_positive],axis=0)
np.shape(train_data)


## reverse the test data
#test_data=1-test_data
###np.shape(train_data) # (60000,28,28)
###input_shape = np.shape(train_data)[1:] # python start from zero, the zero th is the number of images
####K.image_data_format()

###build sequential model
model = keras.Sequential()

model.add(Conv2D(filters=6, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu', input_shape=(32,32,1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=16, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(units=120, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=84, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=10, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),#SGD(learning_rate=learning_rate),
              metrics=['accuracy'])

model.summary()
### training
training_process=model.fit(train_data, train_label,
          batch_size=mini_batch_size,
          epochs=number_epochs,
          verbose=1,
          validation_data=(test_data, test_label))

scores = model.evaluate(test_data, test_label, verbose=0)

print('LeNet 5 Training Error: %.4f%%' % (100-training_process.history['accuracy'][number_epochs-1]*100))
print('LeNet 5 Training Loss: %.4f%%' % (training_process.history['loss'][number_epochs-1]*100))
print('LeNet 5 Training Accuracy: %.4f%%' % (training_process.history['accuracy'][number_epochs-1]*100))

print('LeNet 5 Test Error: %.4f%%' % (100-scores[1]*100))
print('LeNet 5 Test Loss: %.4f%%' % (scores[0]*100))
print('LeNet 5 Test Accuracy: %.4f%%' % (scores[1]*100))

plt.figure()
plt.plot(training_process.history['accuracy'], label='train')
plt.plot(training_process.history['val_accuracy'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.figure()
plt.plot(training_process.history['loss'], label='train')
plt.plot(training_process.history['val_loss'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Multiclass Cross Entropy')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_7 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 938/938 [==============================] - 14s 14ms/step - loss: 1.1105 - accuracy: 0.7788 - val_loss: 0.4253 - val_accuracy: 0.9662
# Epoch 2/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.4248 - accuracy: 0.9616 - val_loss: 0.3477 - val_accuracy: 0.9716
# Epoch 3/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.3375 - accuracy: 0.9720 - val_loss: 0.2852 - val_accuracy: 0.9766
# Epoch 4/40
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2808 - accuracy: 0.9770 - val_loss: 0.2482 - val_accuracy: 0.9792
# Epoch 5/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.2390 - accuracy: 0.9810 - val_loss: 0.2101 - val_accuracy: 0.9830
# Epoch 6/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.2102 - accuracy: 0.9826 - val_loss: 0.1898 - val_accuracy: 0.9828
# Epoch 7/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1905 - accuracy: 0.9821 - val_loss: 0.1735 - val_accuracy: 0.9841
# Epoch 8/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1738 - accuracy: 0.9842 - val_loss: 0.1640 - val_accuracy: 0.9845
# Epoch 9/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1622 - accuracy: 0.9854 - val_loss: 0.1572 - val_accuracy: 0.9841
# Epoch 10/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1547 - accuracy: 0.9861 - val_loss: 0.1490 - val_accuracy: 0.9858
# Epoch 11/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1480 - accuracy: 0.9866 - val_loss: 0.1440 - val_accuracy: 0.9866
# Epoch 12/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1416 - accuracy: 0.9874 - val_loss: 0.1438 - val_accuracy: 0.9848
# Epoch 13/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1414 - accuracy: 0.9860 - val_loss: 0.1409 - val_accuracy: 0.9849
# Epoch 14/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1362 - accuracy: 0.9875 - val_loss: 0.1311 - val_accuracy: 0.9876
# Epoch 15/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1355 - accuracy: 0.9869 - val_loss: 0.1377 - val_accuracy: 0.9840
# Epoch 16/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1331 - accuracy: 0.9871 - val_loss: 0.1395 - val_accuracy: 0.9831
# Epoch 17/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1286 - accuracy: 0.9880 - val_loss: 0.1309 - val_accuracy: 0.9864
# Epoch 18/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1264 - accuracy: 0.9892 - val_loss: 0.1381 - val_accuracy: 0.9845
# Epoch 19/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1279 - accuracy: 0.9877 - val_loss: 0.1289 - val_accuracy: 0.9865
# Epoch 20/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1232 - accuracy: 0.9894 - val_loss: 0.1291 - val_accuracy: 0.9860
# Epoch 21/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1213 - accuracy: 0.9903 - val_loss: 0.1273 - val_accuracy: 0.9877
# Epoch 22/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1199 - accuracy: 0.9892 - val_loss: 0.1288 - val_accuracy: 0.9866
# Epoch 23/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1203 - accuracy: 0.9895 - val_loss: 0.1252 - val_accuracy: 0.9868
# Epoch 24/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1227 - accuracy: 0.9893 - val_loss: 0.1210 - val_accuracy: 0.9883
# Epoch 25/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1172 - accuracy: 0.9906 - val_loss: 0.1224 - val_accuracy: 0.9882
# Epoch 26/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1201 - accuracy: 0.9898 - val_loss: 0.1268 - val_accuracy: 0.9854
# Epoch 27/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1196 - accuracy: 0.9888 - val_loss: 0.1289 - val_accuracy: 0.9863
# Epoch 28/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1170 - accuracy: 0.9898 - val_loss: 0.1335 - val_accuracy: 0.9833
# Epoch 29/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1160 - accuracy: 0.9902 - val_loss: 0.1214 - val_accuracy: 0.9873
# Epoch 30/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1162 - accuracy: 0.9896 - val_loss: 0.1191 - val_accuracy: 0.9892
# Epoch 31/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1146 - accuracy: 0.9907 - val_loss: 0.1221 - val_accuracy: 0.9869
# Epoch 32/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1131 - accuracy: 0.9911 - val_loss: 0.1291 - val_accuracy: 0.9851
# Epoch 33/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1158 - accuracy: 0.9901 - val_loss: 0.1173 - val_accuracy: 0.9895
# Epoch 34/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1142 - accuracy: 0.9901 - val_loss: 0.1202 - val_accuracy: 0.9879
# Epoch 35/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1111 - accuracy: 0.9915 - val_loss: 0.1181 - val_accuracy: 0.9884
# Epoch 36/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1118 - accuracy: 0.9910 - val_loss: 0.1152 - val_accuracy: 0.9898
# Epoch 37/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.1126 - accuracy: 0.9905 - val_loss: 0.1247 - val_accuracy: 0.9859
# Epoch 38/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.1132 - accuracy: 0.9903 - val_loss: 0.1198 - val_accuracy: 0.9872
# Epoch 39/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.1121 - accuracy: 0.9909 - val_loss: 0.1253 - val_accuracy: 0.9851
# Epoch 40/40
# 938/938 [==============================] - 13s 13ms/step - loss: 0.1108 - accuracy: 0.9915 - val_loss: 0.1158 - val_accuracy: 0.9884
# LeNet 5 Training Error: 0.9317%
# LeNet 5 Training Loss: 11.2852%
# LeNet 5 Training Accuracy: 99.0683%
# LeNet 5 Test Error: 1.1600%
# LeNet 5 Test Loss: 11.5761%
# LeNet 5 Test Accuracy: 98.8400%
# Text(0, 0.5, 'Multiclass Cross Entropy')
