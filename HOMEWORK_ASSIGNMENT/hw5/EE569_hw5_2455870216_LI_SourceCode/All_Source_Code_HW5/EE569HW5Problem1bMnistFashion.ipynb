# %%
# EE569 HOMEWORK ASSIGNMENT 5
# DATE: Aprile 14th 2021
# NAME: Siyu Li
# ID:2455870216
# E-mail:lisiyu@usc.edu

### training and performance evaluation on fashion_mnist
### adjust the parameter before training according to your need, optimal parameter setting is stated in report an below
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.initializers import Ones, he_normal, GlorotNormal
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt
from keras.models import Sequential

# training parameter
mini_batch_size = 64
number_epochs = 40
learning_rate = 0.0005
number_class=10

kernel_initial = Ones(), he_normal(), GlorotNormal()
kernel_regularizer = l1(0.001), l2(0.001)
# load data
(train_data, train_label), (test_data, test_label) = fashion_mnist.load_data()
np.shape(train_data)
img_rows=np.shape(train_data)[1]
img_cols=np.shape(train_data)[2]

train_data = train_data.reshape(train_data.shape[0], img_rows, img_cols, 1)
test_data = test_data.reshape(test_data.shape[0], img_rows, img_cols, 1)

train_data = np.pad(train_data,((0,0), (2,2), (2,2), (0,0)), 'constant')
test_data = np.pad(test_data,((0,0), (2,2), (2,2), (0,0)), 'constant')

##np.shape(train_data)
train_label = to_categorical(train_label, number_class)
test_label = to_categorical(test_label, number_class)
# normalize data
train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255
###np.shape(train_data) # (60000,28,28)
###input_shape = np.shape(train_data)[1:] # python start from zero, the zero th is the number of images
####K.image_data_format()

###build sequential model
model = keras.Sequential()

model.add(Conv2D(filters=6, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu', input_shape=(32,32,1)))
model.add(MaxPooling2D())

model.add(Conv2D(filters=16, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(units=120, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=84, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=10, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),#SGD(learning_rate=learning_rate),
              metrics=['accuracy'])

model.summary()
### training
training_process=model.fit(train_data, train_label,
          batch_size=mini_batch_size,
          epochs=number_epochs,
          verbose=1,
          validation_data=(test_data, test_label))

scores = model.evaluate(test_data, test_label, verbose=0)

print('LeNet 5 Training Error: %.4f%%' % (100-training_process.history['accuracy'][number_epochs-1]*100))
print('LeNet 5 Training Loss: %.4f%%' % (training_process.history['loss'][number_epochs-1]*100))
print('LeNet 5 Training Accuracy: %.4f%%' % (training_process.history['accuracy'][number_epochs-1]*100))

print('LeNet 5 Test Error: %.4f%%' % (100-scores[1]*100))
print('LeNet 5 Test Loss: %.4f%%' % (scores[0]*100))
print('LeNet 5 Test Accuracy: %.4f%%' % (scores[1]*100))

plt.figure()
plt.plot(training_process.history['accuracy'], label='train')
plt.plot(training_process.history['val_accuracy'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.figure()
plt.plot(training_process.history['loss'], label='train')
plt.plot(training_process.history['val_loss'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Multiclass Cross Entropy')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 938/938 [==============================] - 13s 13ms/step - loss: 1.2509 - accuracy: 0.7008 - val_loss: 0.7549 - val_accuracy: 0.8440
# Epoch 2/40
# 938/938 [==============================] - 10s 10ms/step - loss: 0.7268 - accuracy: 0.8470 - val_loss: 0.6674 - val_accuracy: 0.8578
# Epoch 3/40
# 938/938 [==============================] - 10s 11ms/step - loss: 0.6339 - accuracy: 0.8637 - val_loss: 0.6092 - val_accuracy: 0.8665
# Epoch 4/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.5764 - accuracy: 0.8759 - val_loss: 0.5719 - val_accuracy: 0.8692
# Epoch 5/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.5306 - accuracy: 0.8851 - val_loss: 0.5311 - val_accuracy: 0.8763
# Epoch 6/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.4969 - accuracy: 0.8873 - val_loss: 0.5054 - val_accuracy: 0.8795
# Epoch 7/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.4694 - accuracy: 0.8940 - val_loss: 0.4829 - val_accuracy: 0.8848
# Epoch 8/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.4517 - accuracy: 0.8945 - val_loss: 0.4872 - val_accuracy: 0.8825
# Epoch 9/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.4310 - accuracy: 0.8981 - val_loss: 0.4542 - val_accuracy: 0.8870
# Epoch 10/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.4168 - accuracy: 0.9013 - val_loss: 0.4579 - val_accuracy: 0.8823
# Epoch 11/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.4082 - accuracy: 0.9012 - val_loss: 0.4522 - val_accuracy: 0.8858
# Epoch 12/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.4007 - accuracy: 0.9039 - val_loss: 0.4407 - val_accuracy: 0.8875
# Epoch 13/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3953 - accuracy: 0.9057 - val_loss: 0.4276 - val_accuracy: 0.8952
# Epoch 14/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3889 - accuracy: 0.9059 - val_loss: 0.4220 - val_accuracy: 0.8933
# Epoch 15/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3777 - accuracy: 0.9097 - val_loss: 0.4348 - val_accuracy: 0.8862
# Epoch 16/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3776 - accuracy: 0.9095 - val_loss: 0.4149 - val_accuracy: 0.8953
# Epoch 17/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3713 - accuracy: 0.9102 - val_loss: 0.4199 - val_accuracy: 0.8945
# Epoch 18/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3659 - accuracy: 0.9115 - val_loss: 0.4090 - val_accuracy: 0.8947
# Epoch 19/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3610 - accuracy: 0.9148 - val_loss: 0.4054 - val_accuracy: 0.8987
# Epoch 20/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3618 - accuracy: 0.9137 - val_loss: 0.4078 - val_accuracy: 0.8959
# Epoch 21/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3628 - accuracy: 0.9142 - val_loss: 0.4212 - val_accuracy: 0.8944
# Epoch 22/40
# 938/938 [==============================] - 13s 13ms/step - loss: 0.3561 - accuracy: 0.9155 - val_loss: 0.4093 - val_accuracy: 0.8966
# Epoch 23/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.3536 - accuracy: 0.9170 - val_loss: 0.4138 - val_accuracy: 0.8918
# Epoch 24/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3481 - accuracy: 0.9186 - val_loss: 0.4107 - val_accuracy: 0.8993
# Epoch 25/40
# 938/938 [==============================] - 11s 12ms/step - loss: 0.3470 - accuracy: 0.9188 - val_loss: 0.4021 - val_accuracy: 0.9016
# Epoch 26/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3478 - accuracy: 0.9197 - val_loss: 0.4083 - val_accuracy: 0.9006
# Epoch 27/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.3447 - accuracy: 0.9203 - val_loss: 0.4252 - val_accuracy: 0.8950
# Epoch 28/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3408 - accuracy: 0.9225 - val_loss: 0.4138 - val_accuracy: 0.8947
# Epoch 29/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3436 - accuracy: 0.9209 - val_loss: 0.4004 - val_accuracy: 0.9028
# Epoch 30/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3437 - accuracy: 0.9197 - val_loss: 0.3964 - val_accuracy: 0.9019
# Epoch 31/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.3387 - accuracy: 0.9233 - val_loss: 0.3942 - val_accuracy: 0.9052
# Epoch 32/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3369 - accuracy: 0.9230 - val_loss: 0.3920 - val_accuracy: 0.9028
# Epoch 33/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3379 - accuracy: 0.9227 - val_loss: 0.4037 - val_accuracy: 0.8980
# Epoch 34/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3336 - accuracy: 0.9243 - val_loss: 0.3929 - val_accuracy: 0.9033
# Epoch 35/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3333 - accuracy: 0.9241 - val_loss: 0.4122 - val_accuracy: 0.8982
# Epoch 36/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3339 - accuracy: 0.9237 - val_loss: 0.3914 - val_accuracy: 0.9051
# Epoch 37/40
# 938/938 [==============================] - 12s 13ms/step - loss: 0.3319 - accuracy: 0.9258 - val_loss: 0.4059 - val_accuracy: 0.9025
# Epoch 38/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3298 - accuracy: 0.9264 - val_loss: 0.4077 - val_accuracy: 0.8943
# Epoch 39/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3299 - accuracy: 0.9253 - val_loss: 0.4000 - val_accuracy: 0.8993
# Epoch 40/40
# 938/938 [==============================] - 12s 12ms/step - loss: 0.3321 - accuracy: 0.9251 - val_loss: 0.4077 - val_accuracy: 0.9014
# LeNet 5 Training Error: 7.5717%
# LeNet 5 Training Loss: 33.3190%
# LeNet 5 Training Accuracy: 92.4283%
# LeNet 5 Test Error: 9.8600%
# LeNet 5 Test Loss: 40.7735%
# LeNet 5 Test Accuracy: 90.1400%
# Text(0, 0.5, 'Multiclass Cross Entropy')
