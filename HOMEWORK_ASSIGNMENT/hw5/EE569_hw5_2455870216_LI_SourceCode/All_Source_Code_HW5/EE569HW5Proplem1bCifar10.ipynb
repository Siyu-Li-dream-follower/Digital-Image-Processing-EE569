# %%
# EE569 HOMEWORK ASSIGNMENT 5
# DATE: Aprile 14th 2021
# NAME: Siyu Li
# ID:2455870216
# E-mail:lisiyu@usc.edu

### training and performance evaluation on cifar10
### adjust the parameter before training according to your need, optimal parameter setting is stated in report an below
### optimal : learning rate=0.0005, mini-batch size=16, Number of epochs = 40, regularizer=L2(0.001), initializer= he_normal(), optimizer=’Adam’
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.initializers import Ones, he_normal, GlorotNormal
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt
from keras.models import Sequential
# training parameter
mini_batch_size = 16
number_epochs = 40
learning_rate = 0.0005
number_class=10

kernel_initial = Ones(), he_normal(), GlorotNormal()
kernel_regularizer = l1(0.001), l2(0.001)
# load data
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label = to_categorical(train_label, number_class)
test_label = to_categorical(test_label, number_class)
# normalize data
train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255

input_shape = np.shape(train_data)[1:] # python start from zero, the zero th is the number of images
# build sequential model
model = keras.Sequential()

model.add(Conv2D(filters=6, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu', input_shape=input_shape))
model.add(MaxPooling2D())

model.add(Conv2D(filters=16, kernel_size=(5, 5), kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(units=120, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=84, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation='relu'))

model.add(Dense(units=10, kernel_initializer=kernel_initial[1], kernel_regularizer=kernel_regularizer[1], activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),#optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),#
              metrics=['accuracy'])

model.summary()
# training
training_process=model.fit(train_data, train_label,
          batch_size=mini_batch_size,
          epochs=number_epochs,
          verbose=1,
          validation_data=(test_data, test_label))

scores = model.evaluate(test_data, test_label, verbose=0)

print('LeNet 5 Training Error: %.4f%%' % (100-training_process.history['accuracy'][number_epochs-1]*100))
print('LeNet 5 Training Loss: %.4f%%' % (training_process.history['loss'][number_epochs-1]*100))
print('LeNet 5 Training Accuracy: %.4f%%' % (training_process.history['accuracy'][number_epochs-1]*100))

print('LeNet 5 Test Error: %.4f%%' % (100-scores[1]*100))
print('LeNet 5 Test Loss: %.4f%%' % (scores[0]*100))
print('LeNet 5 Test Accuracy: %.4f%%' % (scores[1]*100))

plt.figure()
plt.plot(training_process.history['accuracy'], label='train')
plt.plot(training_process.history['val_accuracy'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.figure()
plt.plot(training_process.history['loss'], label='train')
plt.plot(training_process.history['val_loss'], label='test')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Multiclass Cross Entropy')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 2.7823 - accuracy: 0.1416 - val_loss: 2.5917 - val_accuracy: 0.2499
# Epoch 2/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.5273 - accuracy: 0.2635 - val_loss: 2.3813 - val_accuracy: 0.3149
# Epoch 3/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 2.3575 - accuracy: 0.3198 - val_loss: 2.2788 - val_accuracy: 0.3521
# Epoch 4/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 2.2754 - accuracy: 0.3540 - val_loss: 2.2332 - val_accuracy: 0.3639
# Epoch 5/40
# 3125/3125 [==============================] - 16s 5ms/step - loss: 2.2161 - accuracy: 0.3715 - val_loss: 2.1688 - val_accuracy: 0.3891
# Epoch 6/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 2.1668 - accuracy: 0.3838 - val_loss: 2.1385 - val_accuracy: 0.3998
# Epoch 7/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 2.1193 - accuracy: 0.4008 - val_loss: 2.0921 - val_accuracy: 0.4133
# Epoch 8/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 2.0817 - accuracy: 0.4179 - val_loss: 2.0704 - val_accuracy: 0.4185
# Epoch 9/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 2.0605 - accuracy: 0.4237 - val_loss: 2.0577 - val_accuracy: 0.4255
# Epoch 10/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 2.0179 - accuracy: 0.4381 - val_loss: 2.0143 - val_accuracy: 0.4381
# Epoch 11/40
# 3125/3125 [==============================] - 16s 5ms/step - loss: 2.0114 - accuracy: 0.4408 - val_loss: 2.0059 - val_accuracy: 0.4371
# Epoch 12/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.9958 - accuracy: 0.4449 - val_loss: 1.9778 - val_accuracy: 0.4518
# Epoch 13/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.9682 - accuracy: 0.4514 - val_loss: 1.9670 - val_accuracy: 0.4534
# Epoch 14/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.9570 - accuracy: 0.4600 - val_loss: 1.9546 - val_accuracy: 0.4512
# Epoch 15/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.9380 - accuracy: 0.4620 - val_loss: 1.9465 - val_accuracy: 0.4575
# Epoch 16/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.9282 - accuracy: 0.4693 - val_loss: 1.9335 - val_accuracy: 0.4626
# Epoch 17/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8991 - accuracy: 0.4776 - val_loss: 1.9172 - val_accuracy: 0.4668
# Epoch 18/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.8955 - accuracy: 0.4778 - val_loss: 1.9064 - val_accuracy: 0.4684
# Epoch 19/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8898 - accuracy: 0.4812 - val_loss: 1.9196 - val_accuracy: 0.4662
# Epoch 20/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.8817 - accuracy: 0.4847 - val_loss: 1.8819 - val_accuracy: 0.4811
# Epoch 21/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8628 - accuracy: 0.4908 - val_loss: 1.8692 - val_accuracy: 0.4831
# Epoch 22/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8464 - accuracy: 0.4949 - val_loss: 1.8552 - val_accuracy: 0.4910
# Epoch 23/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.8376 - accuracy: 0.4995 - val_loss: 1.8567 - val_accuracy: 0.4926
# Epoch 24/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.8295 - accuracy: 0.4985 - val_loss: 1.8616 - val_accuracy: 0.4822
# Epoch 25/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8117 - accuracy: 0.5043 - val_loss: 1.8459 - val_accuracy: 0.4935
# Epoch 26/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.8121 - accuracy: 0.5051 - val_loss: 1.8255 - val_accuracy: 0.5004
# Epoch 27/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.8041 - accuracy: 0.5079 - val_loss: 1.8091 - val_accuracy: 0.5061
# Epoch 28/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7977 - accuracy: 0.5081 - val_loss: 1.8039 - val_accuracy: 0.5053
# Epoch 29/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.7807 - accuracy: 0.5178 - val_loss: 1.8149 - val_accuracy: 0.4962
# Epoch 30/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7692 - accuracy: 0.5225 - val_loss: 1.7965 - val_accuracy: 0.5057
# Epoch 31/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7628 - accuracy: 0.5215 - val_loss: 1.7894 - val_accuracy: 0.5080
# Epoch 32/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7578 - accuracy: 0.5249 - val_loss: 1.7845 - val_accuracy: 0.5080
# Epoch 33/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7510 - accuracy: 0.5245 - val_loss: 1.8149 - val_accuracy: 0.4976
# Epoch 34/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.7351 - accuracy: 0.5330 - val_loss: 1.7772 - val_accuracy: 0.5155
# Epoch 35/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.7302 - accuracy: 0.5297 - val_loss: 1.7530 - val_accuracy: 0.5199
# Epoch 36/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.7252 - accuracy: 0.5330 - val_loss: 1.7508 - val_accuracy: 0.5245
# Epoch 37/40
# 3125/3125 [==============================] - 17s 6ms/step - loss: 1.7153 - accuracy: 0.5343 - val_loss: 1.7611 - val_accuracy: 0.5159
# Epoch 38/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.7142 - accuracy: 0.5349 - val_loss: 1.7424 - val_accuracy: 0.5251
# Epoch 39/40
# 3125/3125 [==============================] - 17s 5ms/step - loss: 1.6989 - accuracy: 0.5394 - val_loss: 1.7336 - val_accuracy: 0.5290
# Epoch 40/40
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.6875 - accuracy: 0.5445 - val_loss: 1.7669 - val_accuracy: 0.5154
# LeNet 5 Training Error: 45.6940%
# LeNet 5 Training Loss: 169.1777%
# LeNet 5 Training Accuracy: 54.3060%
# LeNet 5 Test Error: 48.4600%
# LeNet 5 Test Loss: 176.6851%
# LeNet 5 Test Accuracy: 51.5400%
# Text(0, 0.5, 'Multiclass Cross Entropy')
